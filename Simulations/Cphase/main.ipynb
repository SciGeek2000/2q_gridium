# %% [markdown]
# # CHPASE GATE!
#
# New entry point. Should be easier to keep track of parameters and namespace issues using this new method
#
# NOTE: If you see crazy behavior, it might be because the drive is being amplified too much by trying to scale to a very poor transition

# %% [markdown]
# ## Workflows

# %% [markdown]
# ### Abstracted Workflow

# %%
# %load_ext autoreload
# %autoreload 2

import sys
# sys.path.append('Users/thomasersevim/anaconda3')
sys.path.append('/Users/thomasersevim/QNL/2q_gridium/')
import yaml

from Circuit_Objs.qchard_idealgridium import *
from Circuit_Objs.qchard_fluxonium import *
from Circuit_Objs.qchard_transmon import *
from Circuit_Objs.qchard_coupobj import *
from Circuit_Objs.qchard_evolgates import *
from Tests.coupobj_test import *
from workflow_funcs import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 9
#       6 sys.path.append('/Users/thomasersevim/QNL/2q_gridium/')
#       7 import yaml
# ----> 9 from Circuit_Objs.qchard_idealgridium import *
#      10 from Circuit_Objs.qchard_fluxonium import *
#      11 from Circuit_Objs.qchard_transmon import *
#
# ModuleNotFoundError: No module named 'Circuit_Objs'

# %% [markdown]
# #### Fluxonium-IdealGridium

# %%
fluxonium = Fluxonium(**light_fluxonium_params, **std_fluxonium_sim_params)
gridium = IdealGridium(**soft_IdealGridium_params, **std_IdealGridium_sim_params)
gridium.nlev = 8
fluxonium.nlev = 8

pulse_path = 'yamls/pulses/fluxonium_idealgridium_soft.yaml'
syscfg_path = 'yamls/syscfgs/fluxonium_idealgridium_soft.yaml'

fig = solve_coupled_qubits(fluxonium, gridium, pulse_path=pulse_path, syscfg_path=syscfg_path, n_shown_states=3)
fig.show()

# %% [markdown]
# It seems as if the rate limiting step for simulations that have high ending fidelity is actually simulating the propegator for all combinations of levels (typically 10x10). This does not seem to meaningfully change the graphs, so for trial simulations, truncated nlevs seems to be appropriate. For very complex/large qubit simulations, best practice is to first simulate the eigenvectors/eigenvalues before then saving the object. This saves sucessive solve times for later.

# %% [markdown]
# ### Modular Workflow
#
# When you want to get more in the weeds. Basically the contents of solve_coupled_qubits

# %% [markdown]
# #### SCQTransmon - Soft IdealGridium

# %%
import sys
sys.path.append('Users/thomasersevim/anaconda3')
sys.path.append('/Users/thomasersevim/QNL/2q_gridium/')

import yaml

from Circuit_Objs.qchard_idealgridium import *
from Circuit_Objs.qchard_fluxonium import *
from Circuit_Objs.qchard_transmon import *
from Tests.coupobj_test import *
from workflow_funcs import *

pulse_path = 'yamls/pulses/scqtransmon_idealgridium_soft.yaml'
syscfg_path = 'yamls/syscfgs/scqtransmon_idealgridium_soft.yaml'

with open(pulse_path, 'r') as f:
    data = yaml.safe_load(f)
    pulse_cfg = PulseConfig(**data)

with open(syscfg_path, 'r') as f:
    data = yaml.safe_load(f)
    system_cfg = SystemConfig(**data)
    del data

gridium = IdealGridium(**soft_IdealGridium_params, **std_IdealGridium_sim_params)
transmon = SCQTransmon(0.3,15,0,8,20)
gridium.nlev = 8 #12
transmon.nlev = 8

qubitA = transmon
qubitB = gridium

n_shown_states = 3

qubitA, qubitB = load_qubits(qubitA, qubitB)
qubitA, qubitB = scale_qubitA_transition(qubitA, qubitB, system_cfg)
system = couple_qubits(qubitA, qubitB, system_cfg, pulse_cfg, mute=False)
test_matrix_element(system, system_cfg, system_cfg.driven_qubit, system_cfg.coupling_type, plotting=True, all_transitions=False)
t_points, U_t, phase_accum, fidelity = solve(system, pulse_cfg, system_cfg, solve_method='propagator', mute=False)
fig = visualize_state_propagation(system, system_cfg, t_points, U_t, phase_accum, fidelity, n_shown_states=n_shown_states)
# Out:
# Transmon uncoupled, prescaled transition is 5.683 GHz
# Ideal Gridium uncoupled intended resonant transition is 0.561 GHz
# WARNING: the Transmon's parameters have been rescaled by a factor of 0.099 and may no longer be physically realizable
# Transmon uncoupled, postscaled transition is 0.561 GHz
#
# Intended detuning between 00-03 and 10-13 (2nd minus 1st): 19.556 MHz
# Comparative detuning between 01-02 and 11-12 (2nd minus 1st): -21.905 MHz
# Relative detuning is -41.461 MHz (comparitive - intended)
# Transition to drive: 00 - 03 with frequency 6.1082 GHz
# Comparative transition: 01 - 02 with frequency 6.102274 GHz
# Drive frequency: 6.1082 GHz
# Drive amplitude scale factor: 1.0000
#   0%|          | 0/200 [00:00<?, ?it/s]
# Max fidelity during the simulations:  0.5334475385177624 at 100.0 ns
# ** Final values **
# Fidelity:  0.5334475385177624
#
# Diagonal elements of the evolution operator (amplitudes and phases with respect to E*t in units of pi)
# 00 0.9878135634639974 0.9600104442293821
# 01 0.986129523832151 -0.737388179101393
# 10 0.9843277078363615 0.03246631223491414
# 11 0.9877157496296616 0.1023074572838446
# $(\phi_{00} + \phi_{11} - \phi_{01} - \phi_{10})/\pi=$ -0.33032383936428855
# Time spent in the 2nd state for 00 - 03: 26.4 ns

# %% [markdown]
# #### SCQTransmon - Hard IdealGridium

# %%
import sys
sys.path.append('Users/thomasersevim/anaconda3')
sys.path.append('/Users/thomasersevim/QNL/2q_gridium/')

import yaml
import qutip as qt
# qt.settings.core["auto_tidyup_atol"] = 1e-14
# qt.settings.core["atol"] = 1e-14
# qt.settings.core["auto_tidyup"] = False

from Circuit_Objs.qchard_idealgridium import *
from Circuit_Objs.qchard_fluxonium import *
from Circuit_Objs.qchard_transmon import *
from Tests.coupobj_test import *
from workflow_funcs import *

pulse_path = 'yamls/pulses/scqtransmon_idealgridium_hard.yaml'
syscfg_path = 'yamls/syscfgs/scqtransmon_idealgridium_hard.yaml'

with open(pulse_path, 'r') as f:
    data = yaml.safe_load(f)
    pulse_cfg = PulseConfig(**data)

with open(syscfg_path, 'r') as f:
    data = yaml.safe_load(f)
    system_cfg = SystemConfig(**data)
    del data

gridium = IdealGridium(**hard_IdealGridium_params, **std_IdealGridium_sim_params)
transmon = SCQTransmon(0.3,15,0,8,20)
gridium.nlev_lc = 1000
gridium.nlev = 8
transmon.nlev = 8
transmon._nlev_cutoff = 100

qubitA = transmon
qubitB = gridium

n_shown_states = 3

qubitA, qubitB = load_qubits(qubitA, qubitB)
qubitA, qubitB = scale_qubitA_transition(qubitA, qubitB, system_cfg)
system = couple_qubits(qubitA, qubitB, system_cfg, pulse_cfg, mute=False)
test_matrix_element(system, system_cfg, system_cfg.driven_qubit, system_cfg.coupling_type, plotting=True, all_transitions=False)
t_points, U_t, phase_accum, fidelity = solve(system, pulse_cfg, system_cfg, solve_method='propagator', mute=False)
fig = visualize_state_propagation(system, system_cfg, t_points, U_t, phase_accum, fidelity, n_shown_states=n_shown_states)
# Out:
# Transmon uncoupled, prescaled transition is 5.683 GHz
# Ideal Gridium uncoupled intended resonant transition is 0.405 GHz
# WARNING: the Transmon's parameters have been rescaled by a factor of 0.071 and may no longer be physically realizable
# Transmon uncoupled, postscaled transition is 0.405 GHz
#
# Intended detuning between 00-02 and 10-13 (2nd minus 1st): 0.736 MHz
# Comparative detuning between 01-02 and 11-12 (2nd minus 1st): 0.047 MHz
# Relative detuning is -0.689 MHz (comparitive - intended)
# Transition to drive: 00 - 02 with frequency 2.9832 GHz
# Comparative transition: 01 - 02 with frequency 2.983183 GHz
# Drive frequency: 2.9832 GHz
# Drive amplitude scale factor: 1.0000
#   0%|          | 0/80 [00:00<?, ?it/s]
# Max fidelity during the simulations:  0.40000000000000197 at 0.0 ns
# ** Final values **
# Fidelity:  0.3251750706980975
#
# Diagonal elements of the evolution operator (amplitudes and phases with respect to E*t in units of pi)
# 00 0.9017859887326526 -0.707597158940264
# 01 0.9017826836195643 -0.7075906428380347
# 10 0.8872735772729466 -0.6043369579538272
# 11 0.887279057670978 -0.6043231802903745
# $(\phi_{00} + \phi_{11} - \phi_{01} - \phi_{10})/\pi=$ 7.2615655662011575e-06
# Time spent in the 2nd state for 00 - 02: 0.0 ns

# %%
V = system.V()
V.tidyup(atol=1e-4)
V.check_herm()

# %%
phi = system._objects[0].phi()
print((phi - phi.dag()).norm())  # Should be ~0 or very small

# %% [markdown]
# #### SCQTransmon-Fluxonium

# %%
import sys
sys.path.append('Users/thomasersevim/anaconda3')
sys.path.append('/Users/thomasersevim/QNL/2q_gridium/')

import yaml
import numpy as np
from Circuit_Objs.qchard_idealgridium import *
from Circuit_Objs.qchard_fluxonium import *
from Circuit_Objs.qchard_transmon import *
from Tests.coupobj_test import *
from workflow_funcs import *

pulse_path = 'yamls/pulses/scqtransmon_heavy_fluxonium.yaml'
syscfg_path = 'yamls/syscfgs/scqtransmon_heavy_fluxonium.yaml'

with open(pulse_path, 'r') as f:
    data = yaml.safe_load(f)
    pulse_cfg = PulseConfig(**data)

with open(syscfg_path, 'r') as f:
    data = yaml.safe_load(f)
    system_cfg = SystemConfig(**data)
    del data

# Taken from https://arxiv.org/abs/2206.06203v2
transmon = SCQTransmon(0.2558, 10.5319, 0, 8, 30)
fluxonium = Fluxonium(0.5, 1, 8, np.pi, 8, 100) # Drive should be on this one (qubitB)

qubitA = transmon
qubitB = fluxonium
n_shown_states = 3

qubitA, qubitB = load_qubits(qubitA, qubitB)
qubitA, qubitB = scale_qubitA_transition(qubitA, qubitB, system_cfg)
system = couple_qubits(qubitA, qubitB, system_cfg, pulse_cfg, mute=False) # Coupling should be capacitive
test_matrix_element(system, system_cfg, system_cfg.driven_qubit, system_cfg.coupling_type, plotting=True, all_transitions=False)
t_points, U_t, phase_accum, fidelity = solve(system, pulse_cfg, system_cfg, solve_method='propagator', mute=False)
fig = visualize_state_propagation(system, system_cfg, t_points, U_t, phase_accum, fidelity, n_shown_states=n_shown_states)
# Out:
# Transmon uncoupled, prescaled transition is 4.370 GHz
# Fluxonium uncoupled intended resonant transition is 6.711 GHz
# Transmon uncoupled, postscaled transition is 6.711 GHz
#
# Intended detuning between 00-03 and 10-13 (2nd minus 1st): 0.615 MHz
# Comparative detuning between 01-02 and 11-12 (2nd minus 1st): 1.258 MHz
# Relative detuning is 0.643 MHz (comparitive - intended)
# Transition to drive: 00 - 03 with frequency 7.2638 GHz
# Comparative transition: 01 - 02 with frequency 6.630390 GHz
# Drive frequency: 7.2641 GHz
# Drive amplitude scale factor: 1.0000
#   0%|          | 0/166 [00:00<?, ?it/s]
# Max fidelity during the simulations:  0.9831168340395319 at 83.0 ns
# ** Final values **
# Fidelity:  0.9831168340395319
#
# Diagonal elements of the evolution operator (amplitudes and phases with respect to E*t in units of pi)
# 00 0.999819797404638 -0.9799998540045369
# 01 0.9996988171446092 -0.010448659278295266
# 10 0.9999939582605567 0.9497394124847588
# 11 0.9945315005555022 -0.024752964985749432
# $(\phi_{00} + \phi_{11} - \phi_{01} - \phi_{10})/\pi=$ 1.0975825843258415
# Time spent in the 2nd state for 00 - 03: 34.6 ns

# %% [markdown]
# #### Light Fluxonium - Soft IdealGridium

# %%
import sys
sys.path.append('Users/thomasersevim/anaconda3')
sys.path.append('/Users/thomasersevim/QNL/2q_gridium/')
import yaml

from Circuit_Objs.qchard_idealgridium import *
from Circuit_Objs.qchard_fluxonium import *
from Circuit_Objs.qchard_transmon import *
from Tests.coupobj_test import *
from workflow_funcs import *

pulse_path = 'yamls/pulses/fluxonium_idealgridium_soft.yaml'
syscfg_path = 'yamls/syscfgs/fluxonium_idealgridium_soft.yaml'

with open(pulse_path, 'r') as f:
    data = yaml.safe_load(f)
    pulse_cfg = PulseConfig(**data)

with open(syscfg_path, 'r') as f:
    data = yaml.safe_load(f)
    system_cfg = SystemConfig(**data)
    del data

gridium = IdealGridium(**soft_IdealGridium_params, **std_IdealGridium_sim_params)
fluxonium = Fluxonium(**light_fluxonium_params, **std_fluxonium_sim_params)
gridium.nlev = 8
fluxonium.nlev = 8

qubitA = fluxonium
qubitB = gridium
n_shown_states = 3

qubitA, qubitB = load_qubits(qubitA, qubitB)
qubitA, qubitB = scale_qubitA_transition(qubitA, qubitB, system_cfg)
system = couple_qubits(qubitA, qubitB, system_cfg, pulse_cfg, mute=False)
test_matrix_element(system, system_cfg, system_cfg.driven_qubit, system_cfg.coupling_type, plotting=True, all_transitions=False)
t_points, U_t, phase_accum, fidelity = solve(system, pulse_cfg, system_cfg, solve_method='propagator', mute=False)
fig = visualize_state_propagation(system, system_cfg, t_points, U_t, phase_accum, fidelity, n_shown_states=n_shown_states)
# Out:
# Fluxonium uncoupled, prescaled transition is 0.607 GHz
# Ideal Gridium uncoupled intended resonant transition is 0.561 GHz
# Fluxonium uncoupled, postscaled transition is 0.561 GHz
#
# Intended detuning between 00-03 and 10-13 (2nd minus 1st): -0.002 MHz
# Comparative detuning between 01-02 and 11-12 (2nd minus 1st): 0.068 MHz
# Relative detuning is 0.070 MHz (comparitive - intended)
# Transition to drive: 00 - 03 with frequency 6.1068 GHz
# Comparative transition: 01 - 02 with frequency 6.105197 GHz
# Drive frequency: 6.1068 GHz
# Drive amplitude scale factor: 1.0000
#   0%|          | 0/80 [00:00<?, ?it/s]
# Max fidelity during the simulations:  0.3999999999999992 at 0.0 ns
# ** Final values **
# Fidelity:  0.3999423110251728
#
# Diagonal elements of the evolution operator (amplitudes and phases with respect to E*t in units of pi)
# 00 0.9999633355386496 0.886020877762516
# 01 0.9998203305921441 0.8883626359543266
# 10 0.9999663567981978 0.8843782731987007
# 11 0.9998270952723622 0.8866368636764154
# $(\phi_{00} + \phi_{11} - \phi_{01} - \phi_{10})/\pi=$ -8.275165432666484e-05
# Time spent in the 2nd state for 00 - 03: 10.8 ns

# %% [markdown]
# #### Light Fluxonium - Hard IdealGridium

# %%
import sys
sys.path.append('Users/thomasersevim/anaconda3')
sys.path.append('/Users/thomasersevim/QNL/2q_gridium/')
import yaml
import qutip as qt
# qt.settings.core["auto_tidyup_atol"] = 1e-20
# qt.settings.core["atol"] = 1e-20
# qt.settings.core["auto_tidyup"] = False

from Circuit_Objs.qchard_idealgridium import *
from Circuit_Objs.qchard_fluxonium import *
from Circuit_Objs.qchard_transmon import *
from Tests.coupobj_test import *
from workflow_funcs import *

pulse_path = 'yamls/pulses/fluxonium_idealgridium_hard.yaml'
syscfg_path = 'yamls/syscfgs/fluxonium_idealgridium_hard.yaml'

with open(pulse_path, 'r') as f:
    data = yaml.safe_load(f)
    pulse_cfg = PulseConfig(**data)

with open(syscfg_path, 'r') as f:
    data = yaml.safe_load(f)
    system_cfg = SystemConfig(**data)
    del data

gridium = IdealGridium(**hard_IdealGridium_params, **std_IdealGridium_sim_params)
fluxonium = Fluxonium(**light_fluxonium_params, **std_fluxonium_sim_params)
gridium.nlev_lc = 1000
gridium.nlev = 12
fluxonium.nlev = 12

qubitA = fluxonium
qubitB = gridium
n_shown_states = 3

qubitA, qubitB = load_qubits(qubitA, qubitB)
qubitA, qubitB = scale_qubitA_transition(qubitA, qubitB, system_cfg)
system = couple_qubits(qubitA, qubitB, system_cfg, pulse_cfg, mute=False)
test_matrix_element(system, system_cfg, system_cfg.driven_qubit, system_cfg.coupling_type, plotting=True, all_transitions=False)
t_points, U_t, phase_accum, fidelity = solve(system, pulse_cfg, system_cfg, solve_method='propagator', mute=False)
fig = visualize_state_propagation(system, system_cfg, t_points, U_t, phase_accum, fidelity, n_shown_states=n_shown_states)
# Out:
# Fluxonium uncoupled, prescaled transition is 0.607 GHz
# Ideal Gridium uncoupled intended resonant transition is 0.405 GHz
# Fluxonium uncoupled, postscaled transition is 0.405 GHz
#
# Intended detuning between 00-02 and 10-13 (2nd minus 1st): 3.811 MHz
# Comparative detuning between 01-02 and 11-12 (2nd minus 1st): -68.365 MHz
# Relative detuning is -72.176 MHz (comparitive - intended)
# Transition to drive: 00 - 02 with frequency 2.9844 GHz
# Comparative transition: 01 - 02 with frequency 2.981427 GHz
# Drive frequency: 2.9844 GHz
# Drive amplitude scale factor: 1.0000
#   0%|          | 0/200 [00:00<?, ?it/s]
# Max fidelity during the simulations:  0.4489634853182102 at 100.0 ns
# ** Final values **
# Fidelity:  0.4489634853182102
#
# Diagonal elements of the evolution operator (amplitudes and phases with respect to E*t in units of pi)
# 00 0.9988860417485115 0.9073602582336923
# 01 0.9981534861134908 -0.9426459155898284
# 10 0.9567664489045283 0.6859323670924864
# 11 0.9788944476528386 -0.8441072314690206
# $(\phi_{00} + \phi_{11} - \phi_{01} - \phi_{10})/\pi=$ -0.20979834761654534
# Time spent in the 2nd state for 00 - 02: 27.4 ns

# %%
import sys
sys.path.append('Users/thomasersevim/anaconda3')
sys.path.append('/Users/thomasersevim/QNL/2q_gridium/')
import yaml
import qutip as qt
# qt.settings.core["auto_tidyup_atol"] = 1e-20
# qt.settings.core["atol"] = 1e-20
# qt.settings.core["auto_tidyup"] = False

from Circuit_Objs.qchard_idealgridium import *
from Circuit_Objs.qchard_fluxonium import *
from Circuit_Objs.qchard_transmon import *
from Tests.coupobj_test import *
from workflow_funcs import *

pulse_path = 'yamls/pulses/fluxonium_idealgridium_hard.yaml'
syscfg_path = 'yamls/syscfgs/fluxonium_idealgridium_hard.yaml'

with open(pulse_path, 'r') as f:
    data = yaml.safe_load(f)
    pulse_cfg = PulseConfig(**data)

with open(syscfg_path, 'r') as f:
    data = yaml.safe_load(f)
    system_cfg = SystemConfig(**data)
    del data

gridium = IdealGridium(**hard_IdealGridium_params, **std_IdealGridium_sim_params)
fluxonium = Fluxonium(**light_fluxonium_params, **std_fluxonium_sim_params)
gridium.nlev_lc = 1000
gridium.nlev = 12
fluxonium.nlev = 12

qubitA = fluxonium
qubitB = gridium
n_shown_states = 3

qubitA, qubitB = load_qubits(qubitA, qubitB)
qubitA, qubitB = scale_qubitA_transition(qubitA, qubitB, system_cfg)
system = couple_qubits(qubitA, qubitB, system_cfg, pulse_cfg, mute=False)
test_matrix_element(system, system_cfg, system_cfg.driven_qubit, system_cfg.coupling_type, plotting=True, all_transitions=False)
t_points, U_t, phase_accum, fidelity = solve(system, pulse_cfg, system_cfg, solve_method='propagator', mute=False)
fig = visualize_state_propagation(system, system_cfg, t_points, U_t, phase_accum, fidelity, n_shown_states=n_shown_states)
# Out:
# Fluxonium uncoupled, prescaled transition is 0.607 GHz
# Ideal Gridium uncoupled intended resonant transition is 0.405 GHz
# Fluxonium uncoupled, postscaled transition is 0.405 GHz
#
# Intended detuning between 00-02 and 10-13 (2nd minus 1st): 2.842 MHz
# Comparative detuning between 01-02 and 11-12 (2nd minus 1st): -3.249 MHz
# Relative detuning is -6.091 MHz (comparitive - intended)
# Transition to drive: 00 - 02 with frequency 2.9832 GHz
# Comparative transition: 01 - 02 with frequency 2.982886 GHz
# Drive frequency: 2.9832 GHz
# Drive amplitude scale factor: 1.0000
#   0%|          | 0/400 [00:00<?, ?it/s]
# Max fidelity during the simulations:  0.3999999999999996 at 0.0 ns
# ** Final values **
# Fidelity:  0.3859270259569742
#
# Diagonal elements of the evolution operator (amplitudes and phases with respect to E*t in units of pi)
# 00 0.9894324703264084 0.9553724642421549
# 01 0.9798452056630397 0.9666425901459527
# 10 0.967349673262241 0.958070070382938
# 11 0.9568075236672896 0.9586289816745969
# $(\phi_{00} + \phi_{11} - \phi_{01} - \phi_{10})/\pi=$ -0.017545379370079942
# Time spent in the 2nd state for 00 - 02: 55.2 ns

# %% [markdown]
# ## Saving Diagonalized Objects
#
# For speed in later use

# %%
# gridium = IdealGridium(**soft_IdealGridium_params, **std_IdealGridium_sim_params)
# gridium.nlev = 10
# gridium.levels(eigvecs=True)
# gridium.save_obj('/Users/thomasersevim/QNL/2q_gridium/etc/qubits/')

# fluxonium = Fluxonium(**fluxonium_params, **std_fluxonium_sim_params)
# fluxonium.nlev = 10
# fluxonium.levels(eigvecs=True)
# fluxonium.save_obj('/Users/thomasersevim/QNL/2q_gridium/etc/qubits/')

# qubitA.levels(eigvecs=True)
# qubitA.save_obj('/Users/thomasersevim/QNL/2q_gridium/etc/qubits/')
qubitB.levels(eigvecs=True)
qubitB.save_obj('/Users/thomasersevim/QNL/2q_gridium/etc/qubits/')

# %% [markdown]
# ## Testing

# %%
transmon = SCQTransmon(0.3, 15, 0, 6, 8)
transmon.nlev_lc = 1000
transmon.nlev = 20
print(transmon.transition_energies())
